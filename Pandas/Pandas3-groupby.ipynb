# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datasets/weather.csv')
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
groups = df.groupby('city')

# %%
print(groups)

# %%
for city,city_df in groups:
    print(city)
    print(city_df)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
groups.get_group('mumbai')
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %%
groups.max()    #same mean(),describe()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
print(groups.aggregate(np.mean))
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
print(groups.aggregate(np.max))
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %% [markdown]
# ### if column is string/object it will take values a/c to alphabetical order

# %%
groups.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
np.set_printoptions(threshold=np.nan)
groups.describe(include = 'all')
# Out:
#            day                                                      ...   \
#          count unique       top freq mean  std  min  25%  50%  75%  ...
# city                                                                ...
# mumbai       4      4  1/1/2017    1  NaN  NaN  NaN  NaN  NaN  NaN  ...
# new york     4      4  1/1/2017    1  NaN  NaN  NaN  NaN  NaN  NaN  ...
# paris        4      4  1/1/2017    1  NaN  NaN  NaN  NaN  NaN  NaN  ...
#
#          windspeed
#             unique top freq   mean       std  min   25%   50%    75%   max
# city
# mumbai         NaN NaN  NaN   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       NaN NaN  NaN   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          NaN NaN  NaN  12.75  5.251984  8.0  9.50  11.5  14.75  20.0
#
# [3 rows x 44 columns]

# %%
groups.dtypes
# Out:
#              day   event temperature windspeed
# city
# mumbai    object  object       int64     int64
# new york  object  object       int64     int64
# paris     object  object       int64     int64

# %%
groups.describe(exclude=['object'])
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
df.groupby('city')['city'].count().sort_values(ascending=False)
# Out:
# city
# paris       4
# new york    4
# mumbai      4
# Name: city, dtype: int64

# %%
#another way of doing this is value count
df['city'].value_counts()
# Out:
# mumbai      4
# paris       4
# new york    4
# Name: city, dtype: int64
