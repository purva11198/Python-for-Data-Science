# %%
l = []

# %%
type(l)
# Out:
# list

# %%
l.append(45)

# %%
l
# Out:
# [45]

# %%
l = [12, "apples"]

# %%
l
# Out:
# [12, 'apples']

# %%
l[1]
# Out:
# 'apples'

# %%
l2 = ["fruits", l]

# %%
l2
# Out:
# ['fruits', [12, 'apples']]

# %%
l2[1]
# Out:
# [12, 'apples']

# %%
l2[1][1]
# Out:
# 'apples'

# %%
len("qwerfghjk")
# Out:
# 9

# %%
l = list("apple")

# %%
l
# Out:
# ['a', 'p', 'p', 'l', 'e']

# %%
l.append("apple")

# %%
l
# Out:
# ['a', 'p', 'p', 'l', 'e', 'apple']

# %%
l1 = [1,54,87]
l2 = [10,100,100]

# %%
l1+l2
# Out:
# [1, 54, 87, 10, 100, 100]

# %%
l1 * 3
# Out:
# [1, 54, 87, 1, 54, 87, 1, 54, 87]

# %%
"-"  * 78
# Out:
# '------------------------------------------------------------------------------'

# %%
l1 = [14, 54,100]
l2 = l1

# %%
l1
# Out:
# [14, 54, 100]

# %%
l2
# Out:
# [14, 54, 100]

# %%
l2[0] = 99999

# %%
l2
# Out:
# [99999, 54, 100]

# %%
l1
# Out:
# [99999, 54, 100]

# %%
l2 = l1.copy()

# %%
l2
# Out:
# [99999, 54, 100]

# %%
l2[0] = 4000001

# %%
l2
# Out:
# [4000001, 54, 100]

# %%
l1
# Out:
# [99999, 54, 100]

# %%
l1[-1]
# Out:
# 100
