# %%
# Single line comment

# %% [markdown]
# Markdown text

# %% [markdown]
# # Level 1 Heading

# %%
3+7
# Out:
# 10

# %%
a = 78

# %%
type(a)
# Out:
# int

# %%
d = 71.4545

# %%
type(d)
# Out:
# float

# %%
x = 15
y = 17

# %%
y/x
# Out:
# 1.1333333333333333

# %%
y//x
# Out:
# 1

# %%
y%x
# Out:
# 2

# %%
print(y)
# Out:
# 17

# %%
c = 45+7j

# %%
c
# Out:
# (45+7j)

# %%
type(c)
# Out:
# complex

# %%
d = 4+-5j

# %%
c+d
# Out:
# (49+2j)

# %%
c.conjugate()
# Out:
# (45-7j)

# %%
c
# Out:
# (45+7j)

# %%
c.real
# Out:
# 45.0

# %%
import fractions

# %%
fractions.Fraction(1,78)
# Out:
# Fraction(1, 78)

# %%
from fractions import Fraction

# %%
Fraction(4,5)
# Out:
# Fraction(4, 5)

# %%
from fractions import Fraction as frac

# %%
f1 = frac(1,7)

# %%
f1
# Out:
# Fraction(1, 7)

# %%
f2 = frac(2,8)

# %%
f1
# Out:
# Fraction(1, 7)

# %%
f2
# Out:
# Fraction(1, 4)

# %%
f1 + f2
# Out:
# Fraction(11, 28)

# %%
f1 * f2
# Out:
# Fraction(1, 28)

# %%
x, y, z = 1, 4, 78

# %%
x
# Out:
# 1

# %%
a = b = c = 78

# %%
a
# Out:
# 78

# %%
x > y
# Out:
# False

# %%
x < y
# Out:
# True

# %%
x < 5 or x >10
# Out:
# True

# %%
not (x>5)
# Out:
# True

# %%
int("78")
# Out:
# 78

# %%
int(45.45)
# Out:
# 45

# %%
float(17)
# Out:
# 17.0

# %%
2 ** 4
# Out:
# 16

# %%
bin(7)
# Out:
# '0b111'

# %%
bin(5)
# Out:
# '0b101'

# %%
5 | 7
# Out:
# 7

# %%
5 << 3
# Out:
# 40

# %%
5 >> 3
# Out:
# 0

# %%
bin(4)
# Out:
# '0b100'

# %%
bin(6)
# Out:
# '0b110'

# %%
4 | 6
# Out:
# 6

# %%
s1 = set("banana")

# %%
s1
# Out:
# {'a', 'b', 'n'}

# %%
bin(5)
# Out:
# '0b101'

# %%
5 << 3
# Out:
# 40

# %%
bin(40)
# Out:
# '0b101000'

# %%
5 >> 3
# Out:
# 0

# %%
s1 = set("banana")

# %%
s1
# Out:
# {'a', 'b', 'n'}

# %%
s1, s2 = set("abcde"), set("defgh")

# %%
s1
# Out:
# {'a', 'b', 'c', 'd', 'e'}

# %%
s2
# Out:
# {'d', 'e', 'f', 'g', 'h'}

# %%
s1 - s2
# Out:
# {'a', 'b', 'c'}

# %%
s1 + s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-07ecabcb1b41> in <module>()
# ----> 1 s1 + s2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
s1 | s2
# Out:
# {'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'}

# %%
s1 ^ s2
# Out:
# {'a', 'b', 'c', 'f', 'g', 'h'}

# %%
s1.intersection(s2)
# Out:
# {'d', 'e'}

# %%
s1 & s2
# Out:
# {'d', 'e'}

# %%
s1 > s2
# Out:
# False

# %%
s1 < s2
# Out:
# False

# %%
s1.add("z")

# %%
s1
# Out:
# {'a', 'b', 'c', 'd', 'e', 'z'}

# %%
s1.remove("z")

# %%
s1
# Out:
# {'a', 'b', 'c', 'd', 'e'}
