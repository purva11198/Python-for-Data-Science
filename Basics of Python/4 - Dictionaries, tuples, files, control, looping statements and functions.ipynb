# %%
d = {"name":"Bob", "age":21}

# %%
d
# Out:
# {'name': 'Bob', 'age': 21}

# %%
d["name"]
# Out:
# 'Bob'

# %%
d.get("name")
# Out:
# 'Bob'

# %%
d = dict(name="ABD", age=24)

# %%
d
# Out:
# {'name': 'ABD', 'age': 24}

# %%
d1 = dict(name="ABD", age=24)

# %%
d2 = dict(name="EFG", age=24)

# %%
d1.update(d2)

# %%
d1
# Out:
# {'name': 'EFG', 'age': 24}

# %%
t = 15, 78

# %%
t
# Out:
# (15, 78)

# %%
t[0] = 77
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-a2ab46a5ae0b> in <module>()
# ----> 1 t[0] = 77
#
# TypeError: 'tuple' object does not support item assignment

# %%
t = (4,)

# %%
type(t)
# Out:
# tuple

# %%
t = tuple("assdfd")

# %%
t
# Out:
# ('a', 's', 's', 'd', 'f', 'd')

# %%
t.count("a")
# Out:
# 1

# %%
"esrdfghjkaaa".count("a")
# Out:
# 3

# %%
file = open("new_file.txt", "w")

# %%
file.write("Hello, \End")
# Out:
# 11

# %%
file.close()

# %%
f1 = open("new_file.txt", "r")

# %%
print(f1.read())
# Out:
# Hello, \End

# %%
f1.close()

# %%
x, y = 14, 5

# %%
if x<5:
    print("x is less than 5")
elif x<10:
    print("x is less than 10")
else:
    print("X is greater than 10")
# Out:
# X is greater than 10

# %%
for character in "apple":
    print(character)
# Out:
# a
# p
# p
# l
# e

# %%
for i in range(4,17,5):
    print(i)
# Out:
# 4
# 9
# 14

# %%
d = {"k1":12, "k2":21, "k3":44}

# %%
for k,v in d.items():
    print(k,v,sep=" = ", end=", ")
# Out:
# k1 = 12, k2 = 21, k3 = 44,

# %%
i = 5
while(i<10):
    print(i)
    i += 1
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
for ch in "zebra":
    if ch in "aeiou":
        print("Vowel found!")
        break
else:
    print("No vowel found!")
# Out:
# Vowel found!

# %%
def greet(name):
    print("Hello "+name)

# %%
def add(n1, n2=1):
    return (n1+n2)

# %%
sum = add(14)

# %%
print(45,54, sep=" | ")
# Out:
# 45 | 54

# %%
sum
# Out:
# 15

# %%
def maximum(*vargs):
    """find the maximum of given arguments"""
    return max(*vargs)

# %%
maximum(12,45,45)
# Out:
# 45

# %%
def print_it(**kwargs):
    for k,v in kwargs.items():
        print(k,v,sep=" = ")

# %%
print_it(name="Raj", age = 22)
# Out:
# name = Raj
# age = 22

# %%
s = """multi
line
string
"""

# %%
s
# Out:
# 'multi\nline\nstring\n'

# %%
print(s)
# Out:
# multi
# line
# string

# %%
rep_w = lambda w, c : w*c

# %%
rep_w("hey! ", 16)
# Out:
# 'hey! hey! hey! hey! hey! hey! hey! hey! hey! hey! hey! hey! hey! hey! hey! hey! '

# %%
int_string = "12364"
int_list = list(map(int, int_string))

# %%
sq = lambda i  : i*2

# %%
int_list
# Out:
# [1, 2, 3, 6, 4]

# %%
sq_list = list(map(sq, int_list))

# %%
sq_list
# Out:
# [2, 4, 6, 12, 8]

# %%
input()
# Out:
# 4545 apple
# '4545 apple'

# %%
i = int(input())
# Out:
# 47

# %%
type(i)
# Out:
# int

# %%
"qqqq rrrr".split(" ")
# Out:
# ['qqqq', 'rrrr']

# %%
def rep_times(count):
    def repeater(word):
        print(word*count)
    return repeater

# %%
five_times_repeater = rep_times(5)
two_times_repeater = rep_times(2)

# %%
five_times_repeater("hey ")
# Out:
# hey hey hey hey hey

# %%
two_times_repeater("hey ")
# Out:
# hey hey
