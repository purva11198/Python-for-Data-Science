# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.14.3'

# %%
phonebook = {"Raj":12, "Rahul":78, "Sam":44, "Tim":9898}

# %%
phonebook.get("Raj")
# Out:
# 12

# %%
phonebook["Raj"]
# Out:
# 12

# %%
phonebook["Timothy"] = 94555

# %%
phonebook
# Out:
# {'Raj': 12, 'Rahul': 78, 'Sam': 44, 'Tim': 9898, 'Timothy': 94555}

# %%
phonebook["Raj"] = 9405444444

# %%
phonebook
# Out:
# {'Raj': 9405444444, 'Rahul': 78, 'Sam': 44, 'Tim': 9898, 'Timothy': 94555}

# %%
no = phonebook.pop("Raj")

# %%
no
# Out:
# 9405444444

# %%
phonebook
# Out:
# {'Rahul': 78, 'Sam': 44, 'Tim': 9898, 'Timothy': 94555}

# %%
phonebook["Rahul Kapoor"] = phonebook.pop("Rahul")

# %%
phonebook
# Out:
# {'Sam': 44, 'Tim': 9898, 'Timothy': 94555, 'Rahul Kapoor': 78}

# %%
keys = ["name", "age", "city"]
values = ["Raj", 25, "Pune"]

# %%
t = ("name", "Raj")

# %%
t
# Out:
# ('name', 'Raj')

# %%
zip(keys, values)

# %%
info = dict(zip(keys, values))

# %%
info
# Out:
# {'name': 'Raj', 'age': 25, 'city': 'Pune'}

# %%
for a,b in zip(keys, values):
    print(a,b)
# Out:
# name Raj
# age 25
# city Pune

# %%
a, b = (16, 47)

# %%
a
# Out:
# 16

# %%
b
# Out:
# 47

# %%
d = dict(name="Raj", age=25)

# %%
d
# Out:
# {'name': 'Raj', 'age': 25}

# %%
d = {"name":"raj", "age":25}

# %%
d
# Out:
# {'name': 'raj', 'age': 25}

# %%
only_keys = ["name", "contact_number", "age"]

# %%
d = dict.fromkeys(only_keys)

# %%
d
# Out:
# {'name': None, 'contact_number': None, 'age': None}

# %%
d["name"] = "Sam"

# %%
d
# Out:
# {'name': 'Sam', 'contact_number': None, 'age': None}

# %%
d["contact_number"] = 9405457788

# %%
d["age"] = 25

# %%
d
# Out:
# {'name': 'Sam', 'contact_number': 9405457788, 'age': 25}

# %%
sample = d.pop("contact_number")

# %%
sample
# Out:
# 9405457788

# %%
d
# Out:
# {'name': 'Sam', 'age': 25}

# %%
del d["name"]

# %%
d
# Out:
# {'age': 25}

# %%
d
# Out:
# {'age': 25}

# %%
d.get("name")

# %%
d
# Out:
# {'age': 25}

# %%
d.get("name", "Not available in the dictionary")
# Out:
# 'Not available in the dictionary'

# %%
d.setdefault("name", "Dummy name")
# Out:
# 'Dummy name'

# %%
d
# Out:
# {'age': 25, 'name': 'Dummy name'}
